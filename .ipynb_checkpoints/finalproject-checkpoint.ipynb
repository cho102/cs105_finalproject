# %%
# %matplotlib inline
import pandas as pd
import numpy as np 
import matplotlib.pyplot as plt
from math import pi
import seaborn as sns

import csv

# %%
df = pd.read_csv("yelp_reviews_boba_categories.csv")
df.head()
# Out:
#               business_id         name        address         city state  \
# 0  i9eMSNpOA8BfHGZrM-9sZg  Kung Fu Tea  1469 Brace Rd  Cherry Hill    NJ
# 1  i9eMSNpOA8BfHGZrM-9sZg  Kung Fu Tea  1469 Brace Rd  Cherry Hill    NJ
# 2  i9eMSNpOA8BfHGZrM-9sZg  Kung Fu Tea  1469 Brace Rd  Cherry Hill    NJ
# 3  i9eMSNpOA8BfHGZrM-9sZg  Kung Fu Tea  1469 Brace Rd  Cherry Hill    NJ
# 4  i9eMSNpOA8BfHGZrM-9sZg  Kung Fu Tea  1469 Brace Rd  Cherry Hill    NJ
#
#   postal_code  latitude  longitude  stars  \
# 0       08034  39.88926 -75.015852    4.5
# 1       08034  39.88926 -75.015852    4.5
# 2       08034  39.88926 -75.015852    4.5
# 3       08034  39.88926 -75.015852    4.5
# 4       08034  39.88926 -75.015852    4.5
#
#                                           attributes  \
# 0  {'WiFi': "u'free'", 'RestaurantsTakeOut': 'True'}
# 1  {'WiFi': "u'free'", 'RestaurantsTakeOut': 'True'}
# 2  {'WiFi': "u'free'", 'RestaurantsTakeOut': 'True'}
# 3  {'WiFi': "u'free'", 'RestaurantsTakeOut': 'True'}
# 4  {'WiFi': "u'free'", 'RestaurantsTakeOut': 'True'}
#
#                                           categories                 user_id  \
# 0  Bubble Tea, Juice Bars & Smoothies, Food, Coff...  79nOboO-4_yNuQQ21EAU1A
# 1  Bubble Tea, Juice Bars & Smoothies, Food, Coff...  CSBRNusUV3D8t192J-W1yA
# 2  Bubble Tea, Juice Bars & Smoothies, Food, Coff...  Xc9cAaAlshYfBKOZXg2THA
# 3  Bubble Tea, Juice Bars & Smoothies, Food, Coff...  R8kA79smxR1cy22U5ZQ56w
# 4  Bubble Tea, Juice Bars & Smoothies, Food, Coff...  bhAB5wo9iLsaExSw4apR4g
#
#    review_stars                                               text  \
# 0             5  Extremely Nice and clean I go there everyday l...
# 1             3  This experience was a little underwhelming.  I...
# 2             5  Amazing. Refreshing drinks. There's a shortage...
# 3             4  At first I questioned why there was another KF...
# 4             4  This is the second Kung Fu tea that has sprung...
#
#                   date
# 0  2021-05-18 22:04:32
# 1  2021-06-08 02:05:36
# 2  2021-06-10 19:11:25
# 3  2021-05-18 19:18:18
# 4  2021-07-30 00:24:33

# %%
print(len(df.name.unique()))
print(df.state.unique())
# Out:
# 119
# ['NJ' 'NV' 'AZ' 'FL' 'PA' 'IN' 'TN' 'AB' 'CA' 'MO' 'ID' 'LA' 'IL' 'DE']

# %%
#Total number of reviews for each restaurant
reviewsCount = df.groupby("name")["stars"].count()
plt.figure().set_figwidth(20)
plt.bar(reviewsCount.index,reviewsCount)
plt.xticks(rotation=90)
plt.show()

# %%
#Distribution of star ratings in dataframe
df.groupby(['review_stars']).count().plot(kind='pie', y='text', ylabel="Review Ratings", autopct='%1.0f%%')
# Out:
# <AxesSubplot:ylabel='Review Ratings'>
